# %% [markdown]
# NAMA : DIAN PRAMESTI
#
# NO : PYTN-KS11-005

# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib as mpl

# %%
import matplotlib.pyplot as plt

# %%
# membaca dataset
londoncrime = pd.read_csv('london_crime_by_lsoa.csv')

# %% [markdown]
# link dataset: https://www.kaggle.com/datasets/jboysen/london-crime

# %%
londoncrime
# Out:
#           lsoa_code     borough               major_category  \
# 0         E01001116     Croydon                     Burglary
# 1         E01001646   Greenwich  Violence Against the Person
# 2         E01000677     Bromley  Violence Against the Person
# 3         E01003774   Redbridge                     Burglary
# 4         E01004563  Wandsworth                      Robbery
# ...             ...         ...                          ...
# 13490599  E01000504       Brent              Criminal Damage
# 13490600  E01002504  Hillingdon                      Robbery
# 13490601  E01004165      Sutton                     Burglary
# 13490602  E01001134     Croydon                      Robbery
# 13490603  E01003413      Merton  Violence Against the Person
#
#                        minor_category  value  year  month
# 0         Burglary in Other Buildings      0  2016     11
# 1                      Other violence      0  2016     11
# ...

# %% [markdown]
# keterangan :
# - lsoa_code : this represets a policing area
# - borough : the london borough for which the statistic is related
# - major_category : the major crime category
# - minor_category : the minor crime category
# - value : the count of the crime for that particular borough, in that particular month
# - year : the year of summary statistic
# - month : the month of the summary statistic

# %%
# membaca 5 data teratas
londoncrime.head()
# Out:
#    lsoa_code     borough               major_category  \
# 0  E01001116     Croydon                     Burglary
# 1  E01001646   Greenwich  Violence Against the Person
# 2  E01000677     Bromley  Violence Against the Person
# 3  E01003774   Redbridge                     Burglary
# 4  E01004563  Wandsworth                      Robbery
#
#                 minor_category  value  year  month
# 0  Burglary in Other Buildings      0  2016     11
# 1               Other violence      0  2016     11
# 2               Other violence      0  2015      5
# 3  Burglary in Other Buildings      0  2016      3
# 4            Personal Property      0  2008      6

# %%
# membaca 5 data terbawah
londoncrime.tail()
# Out:
#           lsoa_code     borough               major_category  \
# 13490599  E01000504       Brent              Criminal Damage
# 13490600  E01002504  Hillingdon                      Robbery
# 13490601  E01004165      Sutton                     Burglary
# 13490602  E01001134     Croydon                      Robbery
# 13490603  E01003413      Merton  Violence Against the Person
#
#                        minor_category  value  year  month
# 13490599  Criminal Damage To Dwelling      0  2015      2
# 13490600            Personal Property      1  2015      6
# 13490601       Burglary in a Dwelling      0  2011      2
# 13490602            Business Property      0  2011      5
# 13490603                 Wounding/GBH      0  2015      6

# %%
# melihat tipe data
londoncrime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13490604 entries, 0 to 13490603
# Data columns (total 7 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   lsoa_code       object
#  1   borough         object
#  2   major_category  object
#  3   minor_category  object
#  4   value           int64
#  5   year            int64
#  6   month           int64
# dtypes: int64(3), object(4)
# memory usage: 720.5+ MB

# %%
# melihat statistika deskriptif (mean, max, min, median, dll)
londoncrime.describe()
# Out:
#               value          year         month
# count  1.349060e+07  1.349060e+07  1.349060e+07
# mean   4.779444e-01  2.012000e+03  6.500000e+00
# std    1.771513e+00  2.581989e+00  3.452053e+00
# min    0.000000e+00  2.008000e+03  1.000000e+00
# 25%    0.000000e+00  2.010000e+03  3.750000e+00
# 50%    0.000000e+00  2.012000e+03  6.500000e+00
# 75%    1.000000e+00  2.014000e+03  9.250000e+00
# max    3.090000e+02  2.016000e+03  1.200000e+01

# %%
# melihat nama kolom pada dataset
londoncrime.columns
# Out:
# Index(['lsoa_code', 'borough', 'major_category', 'minor_category', 'value',
#        'year', 'month'],
#       dtype='object')

# %%
# melihat daftar index pada dataset
londoncrime.index.values
# Out:
# array([       0,        1,        2, ..., 13490601, 13490602, 13490603],
#       dtype=int64)

# %%
# melihat baris, kolom pada dataset
londoncrime.shape
# Out:
# (13490604, 7)

# %%
# melihat banyaknya objek null
londoncrime.isnull().sum()
# Out:
# lsoa_code         0
# borough           0
# major_category    0
# minor_category    0
# value             0
# year              0
# month             0
# dtype: int64

# %%
# melihat isi data kolom lsoa_code
londoncrime['lsoa_code']
# Out:
# 0           E01001116
# 1           E01001646
# 2           E01000677
# 3           E01003774
# 4           E01004563
#               ...
# 13490599    E01000504
# 13490600    E01002504
# 13490601    E01004165
# 13490602    E01001134
# 13490603    E01003413
# Name: lsoa_code, Length: 13490604, dtype: object

# %%
# melihat isi data kolom lsoa_code dan borough
londoncrime[['lsoa_code','borough']]
# Out:
#           lsoa_code     borough
# 0         E01001116     Croydon
# 1         E01001646   Greenwich
# 2         E01000677     Bromley
# 3         E01003774   Redbridge
# 4         E01004563  Wandsworth
# ...             ...         ...
# 13490599  E01000504       Brent
# 13490600  E01002504  Hillingdon
# 13490601  E01004165      Sutton
# 13490602  E01001134     Croydon
# 13490603  E01003413      Merton
#
# [13490604 rows x 2 columns]

# %%
# mengganti kolom borough menjadi area
londoncrime.rename(columns={'borough':'area'}, inplace=True )

# %%
# yang awalnya borough menjadi area
londoncrime.head()
# Out:
#    lsoa_code        area               major_category  \
# 0  E01001116     Croydon                     Burglary
# 1  E01001646   Greenwich  Violence Against the Person
# 2  E01000677     Bromley  Violence Against the Person
# 3  E01003774   Redbridge                     Burglary
# 4  E01004563  Wandsworth                      Robbery
#
#                 minor_category  value  year  month
# 0  Burglary in Other Buildings      0  2016     11
# 1               Other violence      0  2016     11
# 2               Other violence      0  2015      5
# 3  Burglary in Other Buildings      0  2016      3
# 4            Personal Property      0  2008      6

# %%
# melihat data berdasarkan posisi
print(londoncrime.iloc[87])
# Out:
# lsoa_code                 E01002193
# area                         Harrow
# major_category              Robbery
# minor_category    Business Property
# value                             0
# year                           2013
# month                            12
# Name: 87, dtype: object

# %%
# melihat data berdasarkan label yaitu area Greenwich
Greenwich = londoncrime.loc[londoncrime['area'] == 'Greenwich']
print(Greenwich)
# Out:
#           lsoa_code       area               major_category  \
# 1         E01001646  Greenwich  Violence Against the Person
# 75        E01001600  Greenwich                     Burglary
# 100       E01001572  Greenwich                        Drugs
# 221       E01001634  Greenwich              Criminal Damage
# 248       E01001635  Greenwich           Theft and Handling
# ...             ...        ...                          ...
# 13490518  E01001665  Greenwich                        Drugs
# 13490546  E01001632  Greenwich              Criminal Damage
# 13490572  E01033735  Greenwich              Criminal Damage
# 13490590  E01001679  Greenwich           Theft and Handling
# 13490594  E01001706  Greenwich              Criminal Damage
#
#                                   minor_category  value  year  month
# 1                                 Other violence      0  2016     11
# 75                   Burglary in Other Buildings      0  2016     11
# ...

# %%
# melihat data berdasarkan kondisi yaitu kategori major roberry
condition = londoncrime['major_category']=='Robbery'
print(condition)
# Out:
# 0           False
# 1           False
# 2           False
# 3           False
# 4            True
#             ...
# 13490599    False
# 13490600     True
# 13490601    False
# 13490602     True
# 13490603    False
# Name: major_category, Length: 13490604, dtype: bool

# %%
londoncrime[condition]
# Out:
#           lsoa_code                  area major_category     minor_category  \
# 4         E01004563            Wandsworth        Robbery  Personal Property
# 7         E01002633              Hounslow        Robbery  Personal Property
# 12        E01003852  Richmond upon Thames        Robbery  Personal Property
# 50        E01001206                Ealing        Robbery  Personal Property
# 66        E01000808               Bromley        Robbery  Personal Property
# ...             ...                   ...            ...                ...
# 13490536  E01002432            Hillingdon        Robbery  Business Property
# 13490557  E01002497            Hillingdon        Robbery  Business Property
# 13490576  E01004270         Tower Hamlets        Robbery  Personal Property
# 13490600  E01002504            Hillingdon        Robbery  Personal Property
# 13490602  E01001134               Croydon        Robbery  Business Property
#
#           value  year  month
# ...

# %%
# menghapus kolom lsoa_code
londoncrime.drop(['lsoa_code'], axis=1, inplace=True)

# %%
# kolom lsoa_code berhasil dihapus
londoncrime
# Out:
#                 area               major_category  \
# 0            Croydon                     Burglary
# 1          Greenwich  Violence Against the Person
# 2            Bromley  Violence Against the Person
# 3          Redbridge                     Burglary
# 4         Wandsworth                      Robbery
# ...              ...                          ...
# 13490599       Brent              Criminal Damage
# 13490600  Hillingdon                      Robbery
# 13490601      Sutton                     Burglary
# 13490602     Croydon                      Robbery
# 13490603      Merton  Violence Against the Person
#
#                        minor_category  value  year  month
# 0         Burglary in Other Buildings      0  2016     11
# 1                      Other violence      0  2016     11
# 2                      Other violence      0  2015      5
# 3         Burglary in Other Buildings      0  2016      3
# 4                   Personal Property      0  2008      6
# ...

# %%
# melihat data di kolom minor_category lebih dari tahun 2007
minor = londoncrime[(londoncrime['year'] > 2007)].groupby(['minor_category','year'])['value'].sum()
minor
# Out:
# minor_category       year
# Assault with Injury  2008    56586
#                      2009    55297
#                      2010    54173
#                      2011    50768
#                      2012    50369
#                              ...
# Wounding/GBH         2012     7151
#                      2013    15526
#                      2014    21556
#                      2015    23431
#                      2016    23525
# Name: value, Length: 288, dtype: int64

# %%
Wounding = minor['Wounding/GBH']
Wounding
# Out:
# year
# 2008     8701
# 2009    10005
# 2010     8033
# 2011     7628
# 2012     7151
# 2013    15526
# 2014    21556
# 2015    23431
# 2016    23525
# Name: value, dtype: int64

# %%
# mengubah menjadi dataframe
dfw = Wounding.to_frame()
dfw
# Out:
#       value
# year
# 2008   8701
# 2009  10005
# 2010   8033
# 2011   7628
# 2012   7151
# 2013  15526
# 2014  21556
# 2015  23431
# 2016  23525

# %%
# rename kolom value menjadi wounding
dfw = dfw.rename(columns={'value': 'Wounding'})
dfw
# Out:
#       Wounding
# year
# 2008      8701
# 2009     10005
# 2010      8033
# 2011      7628
# 2012      7151
# 2013     15526
# 2014     21556
# 2015     23431
# 2016     23525

# %% [markdown]
# # LINE PLOT

# %%
# line plot kategori minor Wounding/GBH
# figsize untuk merubah ukuran
# color untuk merubah warna garis
# linewidth untuk merubah ketebalan garis

dfw.plot(kind='line', figsize=(8,6), color='red', linewidth='2')
plt.title('Wounding/GBH Crimes in London 2008-2016')
plt.ylabel('Number of Crimes')
plt.xlabel('Years')
plt.show()

# %% [markdown]
# keterangan :
#
# pada lineplot Wounding/GBH Crimes in London 2008-2016 diatas jumlah kejahatan mulai mengalami peningkatan pada tahun 2012 hingga 2016. Kejahatan terbanyak dengan total 23523 pada tahun 2016, sedangkan paling sedikit pada tahun 2012 sebesar 7151 kejatahan.

# %%
# melihat total(jumlah) kejahatan Wounding terkecil
dfw.min()
# Out:
# Wounding    7151
# dtype: int64

# %%
# melihat total(jumlah) kejahatan Wounding terbanyak
dfw.max()
# Out:
# Wounding    23525
# dtype: int64

# %%
# melihat tahun kejahatan Wounding paling awal
wmin = dfw.reset_index()
wmin['year'].min()
# Out:
# 2008

# %%
# melihat tahun kejahatan Wounding paling akhir
wmax = dfw.reset_index()
wmax['year'].max()
# Out:
# 2016

# %%
AssaultwithInjury = minor['Assault with Injury']
AssaultwithInjury
# Out:
# year
# 2008    56586
# 2009    55297
# 2010    54173
# 2011    50768
# 2012    50369
# 2013    39929
# 2014    45677
# 2015    48164
# 2016    50038
# Name: value, dtype: int64

# %%
# membuat dataframe assaultwithinjury
df = AssaultwithInjury.to_frame()
df
# Out:
#       value
# year
# 2008  56586
# 2009  55297
# 2010  54173
# 2011  50768
# 2012  50369
# 2013  39929
# 2014  45677
# 2015  48164
# 2016  50038

# %%
# rename kolom
df = df.rename(columns={'value': 'AssaultwithInjury'})
df
# Out:
#       AssaultwithInjury
# year
# 2008              56586
# 2009              55297
# 2010              54173
# 2011              50768
# 2012              50369
# 2013              39929
# 2014              45677
# 2015              48164
# 2016              50038

# %%
# menggabungkan wounding dan AssaultwithInjury
result = pd.concat([dfw, df], axis=1)
result
# Out:
#       Wounding  AssaultwithInjury
# year
# 2008      8701              56586
# 2009     10005              55297
# 2010      8033              54173
# 2011      7628              50768
# 2012      7151              50369
# 2013     15526              39929
# 2014     21556              45677
# 2015     23431              48164
# 2016     23525              50038

# %%
# line plot gabungan Wounding dan Assault with Injury
result.plot()
plt.xlabel('Year')
plt.ylabel('Number of crime')
plt.title('Wounding and Assault With Injury in London 2008-2016')
plt.show()

# %% [markdown]
# keterangan :
#
# pada gabungan line plot wounding dan assault with injury diatas dapat disimpulkan bahwa assault with injury lebih tinggi setiap tahunnya dari pada wounding.

# %%
# melihat area brent
Brent = londoncrime[(londoncrime['area']=='Brent')]
Brent
# Out:
#            area               major_category  \
# 35        Brent           Theft and Handling
# 51        Brent           Theft and Handling
# 63        Brent           Theft and Handling
# 73        Brent             Fraud or Forgery
# 88        Brent  Violence Against the Person
# ...         ...                          ...
# 13490551  Brent           Theft and Handling
# 13490553  Brent    Other Notifiable Offences
# 13490571  Brent                     Burglary
# 13490597  Brent           Theft and Handling
# 13490599  Brent              Criminal Damage
#
#                                   minor_category  value  year  month
# 35                              Theft From Shops      0  2010      1
# 51        Motor Vehicle Interference & Tampering      0  2015      9
# 63                   Theft/Taking of Pedal Cycle      0  2014      9
# 73                            Counted per Victim      0  2009     10
# 88                           Assault with Injury      0  2009      5
# ...

# %%
# melihat area brent kategori kejahatan major lebih dari tahun 2015
gab = Brent[(Brent['year'] > 2015)].groupby(['major_category','year'])['value'].sum()
gab
# Out:
# major_category               year
# Burglary                     2016    2631
# Criminal Damage              2016    2280
# Drugs                        2016    2096
# Fraud or Forgery             2016       0
# Other Notifiable Offences    2016     536
# Robbery                      2016     919
# Sexual Offences              2016       0
# Theft and Handling           2016    9026
# Violence Against the Person  2016    9205
# Name: value, dtype: int64

# %%
# lineplot major_category area brent
gab.plot(kind='line', figsize=(30,5), color='red', linewidth='2')
plt.xlabel('Year')
plt.ylabel('Number of crime')
plt.title('Major Category Area Brent of 2016')
plt.show()

# %% [markdown]
# keterangan:
#
# pada line plot diatas major category area brent pada tahun 2016 yaitu:
# 1. Burglary 2631 kasus
# 2. Criminal Damage 2280 kasus
# 3. Drugs 2096 kasus
# 4. Fraud or Forgery 0 kasus
# 5. Other Notifiable Offences 536 kasus
# 6. Robbery 919 kasus
# 7. Sexual Offences 0 kasus
# 8. Theft and Handling 9026 kasus
# 9. Violence Against the Person 9205 kasus
#
#
# Kasus terbanyak merupakan Violence Against the Person dan terkecil Fraud or Forgery dan Sexual Offences

# %% [markdown]
# # AREA PLOT

# %%
# area plots scripting layer
# stacked  = menentukan bar/plot pada grafik di-stacked (ditumpuk) atau tidak
# alpha = mengatur tingkat transparansi

Wounding.plot(kind='area',alpha=0.5,stacked=True,figsize=(10,5))
plt.title('Wounding/GBH Crimes in London 2008-2016')
plt.ylabel('Number of Crimes')
plt.xlabel('Years')
plt.show()

# %% [markdown]
# keterangan :
#
# pada areaplot Wounding/GBH Crimes in London 2008-2016 diatas jumlah kejahatan mulai mengalami peningkatan pada tahun 2012 hingga 2016. Kejahatan terbanyak dengan total 23523 pada tahun 2016, sedangkan paling sedikit pada tahun 2012 sebesar 7151 kejatahan.

# %%
# area plot major category area brent 2016
gab.plot(kind='area', figsize=(30,5))
plt.xlabel('Year')
plt.ylabel('Number of crime')
plt.title('Major Category Area Brent of 2016')
plt.show()

# %% [markdown]
# keterangan:
#
# pada area plot major category area brent pada yahun 2016 dapat disimpulkan bahwa kasus terbanyak merupakan Violence Against the Person dan terkecil Fraud or Forgery dan Sexual Offences.

# %%
# area plot gabungan wounding dan Assault With Injury
result.plot(kind='area', figsize=(10,5))
plt.xlabel('Year')
plt.ylabel('Number of crime')
plt.title('Wounding and Assault With Injury in London')
plt.show()

# %% [markdown]
# keterangan :
#
# pada gabungan area plot wounding dan assault with injury diatas dapat disimpulkan bahwa assault with injury lebih tinggi setiap tahunnya dari pada wounding.

# %%
# area plot artist layer
ax = result.plot(kind='area',alpha=0.35,figsize=(10,5))
ax.set_title("Wounding and Assault With Injury in London")
ax.set_ylabel('Number of Crimes')
ax.set_xlabel('Years')
plt.show()

# %% [markdown]
# keterangan :
#
# pada gabungan area plot wounding dan assault with injury diatas dapat disimpulkan bahwa assault with injury lebih tinggi setiap tahunnya dari pada wounding.

# %% [markdown]
# #BAR CHART

# %%
result.plot(kind='bar')
plt.title('Wounding 2008-1016')
plt.ylabel('Number of Crimes')
plt.xlabel('Number of case')
plt.show()

# %% [markdown]
# keterangan :
#
# pada gabungan bar chart wounding dan assault with injury diatas dapat disimpulkan bahwa kejahatan assault with injury lebih tinggi setiap tahunnya dari pada kejahatan wounding.

# %%
df.plot(kind='bar', color='green')
plt.title('Assault With Injury 2008-2016')
plt.ylabel('Number of Crimes')
plt.xlabel('Number of case')
plt.show()

# %% [markdown]
# keterangan:
#
# pada bar chart assault with injury dari tahun 2008-2016 dapat disimpulkan bahwa pada tahun 2008 hingga 2012 jumlah kasus mengalami penurun namun jumlah kasus naik kembali pada tahun 2013 hingga 2016. kasus tertinggi pada tahun 2008 dan terendah pada tahun 2013.

# %%
# merubah bar vertikal menjadi horizontal
df.plot(kind='barh')
plt.title('Assault With Injury 2008-1016')
plt.ylabel('Number of Crimes')
plt.xlabel('Number of case')
plt.show()

# %% [markdown]
# keterangan:
#
# pada bar chart horizontal assault with injury dari tahun 2008-2016 dapat disimpulkan bahwa pada tahun 2008 hingga 2012 jumlah kasus mengalami penurun namun jumlah kasus naik kembali pada tahun 2013 hingga 2016. kasus tertinggi pada tahun 2008 dan terendah pada tahun 2013.

# %%
# melihat data di kolom minor_category lebih dari tahun 2007
major = londoncrime[(londoncrime['year'] > 2007)].groupby(['major_category','year'])['value'].sum()
major
# Out:
# major_category               year
# Burglary                     2008     88092
#                              2009     90619
#                              2010     86826
#                              2011     93315
#                              2012     93392
#                                       ...
# Violence Against the Person  2012    150014
#                              2013    146181
#                              2014    185349
#                              2015    218740
#                              2016    232381
# Name: value, Length: 81, dtype: int64

# %%
Violence = major['Violence Against the Person']
Violence
# Out:
# year
# 2008    159844
# 2009    160777
# 2010    157894
# 2011    146901
# 2012    150014
# 2013    146181
# 2014    185349
# 2015    218740
# 2016    232381
# Name: value, dtype: int64

# %%
# membuat dataframe
dfv = Violence.to_frame()
dfv
# Out:
#        value
# year
# 2008  159844
# 2009  160777
# 2010  157894
# 2011  146901
# 2012  150014
# 2013  146181
# 2014  185349
# 2015  218740
# 2016  232381

# %%
# rename kolom
dfv1 = df.rename(columns={'value': 'AssaultwithInjury'})
dfv1
# Out:
#       AssaultwithInjury
# year
# 2008              56586
# 2009              55297
# 2010              54173
# 2011              50768
# 2012              50369
# 2013              39929
# 2014              45677
# 2015              48164
# 2016              50038

# %%
dfv1.plot(kind='bar',figsize=(10,7))
plt.title('Assault With Injury 2008-2016')
plt.ylabel('number of cases')
plt.xlabel('year')

plt.annotate('',xy=(8,55000), xytext=(5,40000), arrowprops=dict(arrowstyle='->', connectionstyle='arc3', color='red', lw=2))

plt.annotate('mengalami kenaikan', xy=(5,50000))
plt.show()

# %% [markdown]
# keterangan:
#
# pada bar chart diatas kategori AssaultwithInjury mengalami kenaikan pada tahun 2013 hingga 2016.

# %%
#Analisa Wilayah berdasarkan jumlah kasus di tahun 2016

area = (londoncrime[(londoncrime['year'] == 2016)].groupby('area')['value'].sum()).sort_values(ascending=False)
area
# Out:
# area
# Westminster               48330
# Lambeth                   34071
# Southwark                 31636
# Newham                    30090
# Tower Hamlets             29253
# Camden                    29183
# Croydon                   28712
# Hackney                   28265
# Haringey                  27174
# Ealing                    27127
# Islington                 27092
# Brent                     26693
# Barnet                    24684
# Hillingdon                24341
# Lewisham                  23904
# Wandsworth                23679
# Greenwich                 22730
# Enfield                   22485
# Hounslow                  22251
# Waltham Forest            20716
# Hammersmith and Fulham    20174
# Bromley                   20164
# Kensington and Chelsea    19580
# Redbridge                 19502
# Havering                  16903
# Barking and Dagenham      16741
# Harrow                    13153
# Bexley                    12840
# Merton                    12755
# ...

# %%
#5 Wilayah teratas berdasar jumlah kasus terbanyak di tahun 2016

top5 = (area.head(5)).sort_values()
top5.plot(kind='bar', figsize=(5, 5), color='red')
plt.xlabel('area')
plt.ylabel('Number of Crime')
plt.title('Top 5 area with the most crimes in 2016')
plt.show()

# %% [markdown]
# keterangan:
#
# pada tahun 2016 5 wilayah dengan kasus terbanyak yaitu tower hamlets, newham, southwark, lambeth, dan westminster. namun kasus paling tinggi berada di wilayah westminster dengan total 48330 kasus

# %% [markdown]
# # PIE CHART

# %%
# pie chart = menggambarkan proporsi dari data
top5.plot(kind='pie',figsize=(5,6),autopct='%1.1f%%', startangle=90, shadow=True)
plt.title('Top 5 area with the most crimes in 2016')
plt.axis('equal')
plt.show()

# %%
# mengganti warna
colors_list = ['aliceblue','aqua','aquamarine','azure','beige','bisque']
top5.plot(kind='pie',figsize=(5,6),autopct='%1.1f%%', startangle=90, shadow=True, colors=colors_list)
plt.title('Top 5 area with the most crimes in 2016')
plt.axis('equal')
plt.show()

# %% [markdown]
# keterangan:
#
# pada pie chart diatas yaitu 5 negara dengan kasus terbanyak pada tahun 2016 sebesar 27.9% kasus terbanyak terjadi diwilayah westminster. dan kasus terkecil berada diwilah newham sebesar 17.4%

# %%
# menampilkan data di wilayah Westminster
westminster=londoncrime[londoncrime['area']=='Westminster']
westminster
# Out:
#                  area               major_category  \
# 21        Westminster           Theft and Handling
# 46        Westminster              Criminal Damage
# 74        Westminster  Violence Against the Person
# 134       Westminster           Theft and Handling
# 165       Westminster           Theft and Handling
# ...               ...                          ...
# 13490302  Westminster  Violence Against the Person
# 13490346  Westminster           Theft and Handling
# 13490386  Westminster                      Robbery
# 13490545  Westminster           Theft and Handling
# 13490565  Westminster           Theft and Handling
#
#                                   minor_category  value  year  month
# 21                         Handling Stolen Goods      0  2012      2
# 46                         Other Criminal Damage      0  2008     11
# 74                                  Wounding/GBH      0  2009      9
# 134       Motor Vehicle Interference & Tampering      1  2014      4
# ...

# %%
# mengetahui jumlah kejadian kejahatan di Westminster berdasarkan wilayah kepolisian
west = westminster[(westminster['year'] > 2015)].groupby(['major_category'])[['value']].agg('sum')
west
# Out:
#                              value
# major_category
# Burglary                      3218
# Criminal Damage               2179
# Drugs                         2049
# Fraud or Forgery                 0
# Other Notifiable Offences      708
# Robbery                       1822
# Sexual Offences                  0
# Theft and Handling           27520
# Violence Against the Person  10834

# %%
# memilih warna untuk masing-masing kategori kejahatan
colors_list = ['#800000', '#9A6324', '#ffe119',
               '#aaffc3', '#911eb4', '#a9a9a9',
               '#4363d8', '#f58231', '#fabed4']

# mengatur tampilan pie
explode_list = [0, 0, 0, 0, 0, 0, 0, 0, 0]

west['value'].plot(kind='pie',
               figsize=(5, 5),
               startangle=90,
               colors=colors_list,
               pctdistance=1.5,
               explode=explode_list)

plt.title('Major Criminal Case in Westminster 2016', y=1.12)
plt.show()

# %% [markdown]
# keterangan:
#
# pada pie chart major criminal case in westminster 2016 dapat disimpulkan bahwa theft and handling memiliki jumlah kejahatan terbanyak dibandingkan kejahan lainnya.

# %% [markdown]
# # HISTOGRAM

# %%
result
# Out:
#       Wounding  AssaultwithInjury
# year
# 2008      8701              56586
# 2009     10005              55297
# 2010      8033              54173
# 2011      7628              50768
# 2012      7151              50369
# 2013     15526              39929
# 2014     21556              45677
# 2015     23431              48164
# 2016     23525              50038

# %%
# membuat histogram kategori wounding and assault with injury
result.plot(kind='hist')
plt.title("histogram of wounding and Assault with Injury 2008-2016")
plt.ylabel('number of years')
plt.xlabel('number of crimes')
plt.show()

# %% [markdown]
# keterangan :
#
# pada histogram wounding dan assault with injury diatas dapat disimpulkan bahwa assault with injury lebih tinggi setiap tahunnya dari pada wounding.

# %%
# membuat dataframe dengan index berupa year dan kolom berupa jenis kejahatan yang terjadi berdasarkan major category
table = londoncrime.pivot_table(values='value',
                        index=['year'],
                        columns=['major_category'],
                        aggfunc=np.sum,
                        fill_value=0)
table
# Out:
# major_category  Burglary  Criminal Damage  Drugs  Fraud or Forgery  \
# year
# 2008               88092            91872  68804              5325
# 2009               90619            85565  60549                 0
# 2010               86826            77897  58674                 0
# 2011               93315            70914  57550                 0
# 2012               93392            62158  51776                 0
# 2013               87222            56206  50278                 0
# 2014               76053            59279  44435                 0
# 2015               70489            62976  39785                 0
# 2016               68285            64071  38914                 0
#
# major_category  Other Notifiable Offences  Robbery  Sexual Offences  \
# year
# 2008                                10112    29627             1273
# 2009                                10644    29568                0
# 2010                                10768    32341                0
# ...

# %%
# membuat histogram jenis kejahatan yang terjadi di london pada tahun 2008-2016 berdasarkan major category
count, bin_edges = np.histogram(table, 15)
table.plot(kind='hist',
           figsize=(15, 6),
           bins=15,
           alpha=0.6,
           stacked=True,
           xticks=bin_edges
           )

plt.title('Histogram of major criminal in 2008-2016')
plt.ylabel('Number of Years')
plt.xlabel('Number of Criminal ')

plt.show()

# %% [markdown]
# berdasarkan histogram diatas kejahatan berdasarkan kategori major yang terjadi di London dari tahun 2008-2016 adalah burlgary, criminal damage, drugs, fraud and forgery, other nofiable offences, robbery, sexual offences, theft and handling dan violence agains the person.
# Theft and Handling memiliki jumlah kriminal tertinggi yaitu 334054 kasus sepanjang 2008-2016.

# %%
# membuat dataframe dengan index berupa year dan kolom berupa jenis kejahatan yang terjadi berdasarkan minor category
table1 = londoncrime.pivot_table(values='value',
                        index=['year'],
                        columns=['minor_category'],
                        aggfunc=np.sum,
                        fill_value=0)
table1
# Out:
# minor_category  Assault with Injury  Burglary in Other Buildings  \
# year
# 2008                          56586                        31437
# 2009                          55297                        30434
# 2010                          54173                        29703
# 2011                          50768                        30876
# 2012                          50369                        31676
# 2013                          39929                        30685
# 2014                          45677                        27078
# 2015                          48164                        25833
# 2016                          50038                        25289
#
# minor_category  Burglary in a Dwelling  Business Property  Common Assault  \
# year
# 2008                             56655               2964           37356
# 2009                             60185               3115           39671
# 2010                             57123               3041           41591
# ...

# %%
# membuat histogram jenis kejahatan yang terjadi di london pada tahun 2008-2016 berdasarkan minor category
count, bin_edges = np.histogram(table, 15)
table1.plot(kind='hist',figsize=(20, 6),
           bins=15,
           alpha=0.6,
           stacked=True,
           xticks=bin_edges
           )

plt.title('Histogram of minor criminal in 2008-2016')
plt.ylabel('Number of Years')
plt.xlabel('Number of Criminal ')

plt.show()

# %% [markdown]
# berdasarkan histogram diatas kejahatan berdasarkan kategori minor yang terjadi di London dari tahun 2008-2016 adalah Assault with Injury, Burglary in Other, Buildings, Burglary in a Dwelling, Business Property, Common Assault, Counted per Victim, Criminal Damage To Dwelling, Criminal Damage To Motor Vehicle, Criminal Damage To Other Building, Drug Trafficking, Going Equipped, Handling Stolen Goods,Harassment, Motor Vehicle Interference & Tampering, Murder,Offensive Weapon, Other Criminal Damage, Other Drugs, Other Fraud & Forgery, Other Notifiable, Other Sexual, Other Theft, Other Theft Person, Other violence,Personal Property, Possession Of Drugs, Rape, Theft From Motor Vehicle, Theft From Shops, Theft/Taking Of Motor Vehicle, Theft/Taking of Pedal Cycle, Wounding/GBH.
# kejahatan terbanyak sepanjang 2008-2016 adalah Other Theft dengan jumlah 132056 selama 8 tahun terakhir.

# %% [markdown]
# # BOXPLOT

# %%
df.describe()
# Out:
#        AssaultwithInjury
# count           9.000000
# mean        50111.222222
# std          5159.310704
# min         39929.000000
# 25%         48164.000000
# 50%         50369.000000
# 75%         54173.000000
# max         56586.000000

# %%
df.plot(kind='box', figsize=(8,6))
plt.title('box plot of major category Assault with Injury from 2008-2016')
plt.ylabel('number of crime')
plt.show()

# %% [markdown]
# keterangan:
#
# pada boxplot tersebut menunjukkan bahwa assault with injury pada 2008-2016 memiliki rata rata 50111.222222. minimum 39929.000000, dan maximum 56586.000000.

# %%
result.plot(kind='box', figsize=(8,6))
plt.title('box plot of major category Assault with Injury and Wounding')
plt.ylabel('number of crime')
plt.show()

# %% [markdown]
# keterangan:
#
# pada boxplot tersebut menunjukkan bahwa rata rata assault with injury pada 2008-2016 memiliki rata rata 50111.222222 lebih tinggi dibandingkan rata rata wounding yang sebesar 13950.666667.

# %%
result.describe()
# Out:
#            Wounding  AssaultwithInjury
# count      9.000000           9.000000
# mean   13950.666667       50111.222222
# std     7125.877086        5159.310704
# min     7151.000000       39929.000000
# 25%     8033.000000       48164.000000
# 50%    10005.000000       50369.000000
# 75%    21556.000000       54173.000000
# max    23525.000000       56586.000000

# %%
result.plot(kind='box', figsize=(8,6), vert=False)
plt.title('box plot of major category Assault with Injury and Wounding')
plt.ylabel('number of crime')
plt.show()

# %% [markdown]
# keterangan:
#
# pada boxplot horizontal tersebut menunjukkan bahwa rata rata assault with injury pada 2008-2016 memiliki rata rata 50111.222222 lebih tinggi dibandingkan rata rata wounding yang sebesar 13950.666667.

# %% [markdown]
# # SCATTER PLOT

# %%
major
# Out:
# major_category               year
# Burglary                     2008     88092
#                              2009     90619
#                              2010     86826
#                              2011     93315
#                              2012     93392
#                                       ...
# Violence Against the Person  2012    150014
#                              2013    146181
#                              2014    185349
#                              2015    218740
#                              2016    232381
# Name: value, Length: 81, dtype: int64

# %%
b  = major['Burglary']
b
# Out:
# year
# 2008    88092
# 2009    90619
# 2010    86826
# 2011    93315
# 2012    93392
# 2013    87222
# 2014    76053
# 2015    70489
# 2016    68285
# Name: value, dtype: int64

# %%
b = b.to_frame()
b
# Out:
#       value
# year
# 2008  88092
# 2009  90619
# 2010  86826
# 2011  93315
# 2012  93392
# 2013  87222
# 2014  76053
# 2015  70489
# 2016  68285

# %%
b = b.rename(columns={'value':'total'})
b
# Out:
#       total
# year
# 2008  88092
# 2009  90619
# 2010  86826
# 2011  93315
# 2012  93392
# 2013  87222
# 2014  76053
# 2015  70489
# 2016  68285

# %%
burglary = b.reset_index()
burglary
# Out:
#    year  total
# 0  2008  88092
# 1  2009  90619
# 2  2010  86826
# 3  2011  93315
# 4  2012  93392
# 5  2013  87222
# 6  2014  76053
# 7  2015  70489
# 8  2016  68285

# %%
burglary.plot(kind='scatter', x='year', y='total', figsize=(10,6),color='black')
plt.title('Burglary Crimes From 2008-2016')
plt.xlabel('Year')
plt.ylabel('Number of Crimes')
plt.show()

# %% [markdown]
# keterangan:
#
# pada scatter plot diatas dapat disimpulkan bahwa kategori burglary semakin menurun setiap tahunnya yaitu pada tahun 2012-2016 yang mengalami penurunan cukup pesat.

# %%
result
# Out:
#       Wounding  AssaultwithInjury
# year
# 2008      8701              56586
# 2009     10005              55297
# 2010      8033              54173
# 2011      7628              50768
# 2012      7151              50369
# 2013     15526              39929
# 2014     21556              45677
# 2015     23431              48164
# 2016     23525              50038

# %%
result.reset_index(inplace=True)
result
# Out:
#    year  Wounding  AssaultwithInjury
# 0  2008      8701              56586
# 1  2009     10005              55297
# 2  2010      8033              54173
# 3  2011      7628              50768
# 4  2012      7151              50369
# 5  2013     15526              39929
# 6  2014     21556              45677
# 7  2015     23431              48164
# 8  2016     23525              50038

# %%
w = (result['Wounding']-result['Wounding'].min()) / (result['Wounding'].max() - result['Wounding'].min())

a = (result['AssaultwithInjury']-result['AssaultwithInjury'].min()) / (result['AssaultwithInjury'].max() - result['AssaultwithInjury'].min())

# %%
x0 =  result.plot(kind='scatter', x='year', y='Wounding', figsize=(10, 8), alpha=0.5, color="red", s=w* 1000 +10, xlim=(2008,2016))

x1 =  result.plot(kind='scatter', x='year', y='AssaultwithInjury', alpha=0.5, color="blue", s=a * 1000 +10, ax = x0)

x0.set_ylabel('Number of Crimes')
x0.set_title('Crimes Category Wounding and Assault with Injury from 2008-2016')
x0.legend(['Wounding','AssaultwithInjury'], 
loc='upper left', fontsize='x-large')

# %% [markdown]
# keterangan:
#
# pada gabungan scatter plot assault with injury dan wounding pada 2008-2016 kedua kejatahan tersebut memiliki jumlah kejahatan yang berbeda setiap tahunnya. kejatahan assault with injury lebih tinggi dibanding wounding.

# %% [markdown]
# # kesimpulan
#
# berdasarkan data kejahatan london (london crime data) pada tahun 2008-2016 terdapat 33 wilayah dengan 9 kategori kejahatan major, dan 32 kategori kejahatan minor dapat disimpulkan bahwa:
# - 5 kota dengan kejahatan tertinggi pada tahun 2016 adalah Tower Hamlets    29253 kasus, Newham 30090 kasus, Southwark 31636 kasus, Lambeth 34071 kasus, dan Westminster 48330 kasus.
# - kota dengan tindak kejahatan tertinggi selama 2008-2016 adalah Westminster, sedangkan kota dengan tindak kejahatan terendah selama 2008-2016 adalah City of London sebesar 178 kasus.
# - jenis kejahatan major paling banyak yaitu Theft and Handling dengan jumlah 334054 kasus sepanjang 2008-2016.
# - jenis kejahatan minor paling banyak yaitu Other Theft dengan jumlah 132056 selama 8 tahun terakhir (2008-2016).

# %% [markdown]
# #WORD CLOUDS

# %%
# import wordclouds library
# !pip install wordcloud
from wordcloud import WordCloud, STOPWORDS
# Out:
# ...
#      ------------------------------------ 153.1/153.1 kB 351.8 kB/s eta 0:00:00
# ...

# %%
# kata yang ada pada kolom area
stopwords = list(londoncrime['area'])
stopwords
# Out:
# ['Croydon',
#  'Greenwich',
#  'Bromley',
#  'Redbridge',
#  'Wandsworth',
#  'Ealing',
#  'Ealing',
#  'Hounslow',
#  'Newham',
#  'Sutton',
#  'Haringey',
#  'Lambeth',
#  'Richmond upon Thames',
#  'Wandsworth',
#  'Hillingdon',
#  'Havering',
#  'Barking and Dagenham',
#  'Redbridge',
#  'Kingston upon Thames',
#  'Sutton',
#  'Redbridge',
#  'Westminster',
#  'Hackney',
#  'Enfield',
#  'Ealing',
#  'Hackney',
#  'Harrow',
#  'Ealing',
#  'Haringey',
#  'Lewisham',
#  'Ealing',
#  'Hounslow',
#  'Bromley',
#  'Havering',
#  'Hillingdon',
#  'Brent',
#  'Haringey',
#  'Hounslow',
#  'Lambeth',
#  'Southwark',
#  'Havering',
#  'Newham',
#  'Croydon',
#  'Croydon',
#  'Barnet',
#  'Waltham Forest',
#  'Westminster',
#  'Lambeth',
#  'Lewisham',
#  'Bromley',
#  'Ealing',
#  'Brent',
#  'Haringey',
#  'Camden',
#  'Bexley',
#  'Croydon',
#  'Lewisham',
#  'Hounslow',
#  'Camden',
#  'Kensington and Chelsea',
#  'Hounslow',
#  'Lewisham',
#  'Kingston upon Thames',
#  'Brent',
# ...

# %%
text = ' '.join(londoncrime['area'].astype(str).tolist())

# %%
londoncrime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13490604 entries, 0 to 13490603
# Data columns (total 6 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   area            object
#  1   major_category  object
#  2   minor_category  object
#  3   value           int64
#  4   year            int64
#  5   month           int64
# dtypes: int64(3), object(3)
# memory usage: 617.6+ MB

# %%
lc = WordCloud(width=800, height=800, background_color='white', 
               min_font_size=10).generate(text)

# %%
# wilayah yang sering muncul pada kolom area
fig=plt.figure(figsize=(7,7))
plt.imshow(lc, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# keterangan:
#
# dapat disimpulkan bahwa area richmond upon thames, waltham forest, richmond upon, tower hamlets merupakan area yang sering muncul.

# %%
from PIL import Image

# %%
oipmask = np.array(Image.open('alice_mask.png'))
oipmask
# Out:
# array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8)

# %%
fig = plt.figure()
fig.set_figwidth(5)
fig.set_figheight(5)
plt.imshow(oipmask, cmap=plt.cm.gray, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
plt.imshow(oipmask,cmap=plt.cm.gray)
plt.axis('off')
plt.show()

# %%
stopwords = set(STOPWORDS)

# %%
lc = WordCloud(width=800, height=800, background_color='white', 
               mask=oipmask, stopwords=stopwords)
lc.generate(text)
fig=plt.figure()
plt.imshow(lc, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# # FOLIUM MAPS

# %%
# !pip install folium
import folium
# Out:
# ...
#      ------------------------------------- 102.3/102.3 kB 54.0 kB/s eta 0:00:00
# ...

# %%
#London Lat and Lon
latitude= 51.5085300 #garis lintang
longitude= -0.1257400 #garis bujur

# %%
london = folium.Map(location=[latitude,longitude],zoom_start=12)
london
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
# Mengganti Tipe Peta
london1 = folium.Map(location=[51.5085300,-0.1257400],zoom_start=11,tiles='Stamen Toner')
london1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
area
# Out:
# area
# Westminster               48330
# Lambeth                   34071
# Southwark                 31636
# Newham                    30090
# Tower Hamlets             29253
# Camden                    29183
# Croydon                   28712
# Hackney                   28265
# Haringey                  27174
# Ealing                    27127
# Islington                 27092
# Brent                     26693
# Barnet                    24684
# Hillingdon                24341
# Lewisham                  23904
# Wandsworth                23679
# Greenwich                 22730
# Enfield                   22485
# Hounslow                  22251
# Waltham Forest            20716
# Hammersmith and Fulham    20174
# Bromley                   20164
# Kensington and Chelsea    19580
# Redbridge                 19502
# Havering                  16903
# Barking and Dagenham      16741
# Harrow                    13153
# Bexley                    12840
# Merton                    12755
# ...

# %%
# menampilkan area Camden
camden = folium.Map(location=[51.5405700,-0.1433400],zoom_start=11,tiles='Stamen Terrain')
camden
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
# menampilkan area top5
kota = {
    'area': ['Tower Hamlets', 'Newham', 'Southwark', 'Lambeth', 'Westminster'],
    'latitude': [ 51.520261, 51.525516 , 51.502781, 51.457148, 39.8366528],
    'longitude': [-0.029340, 0.035216, -0.087738, -0.123068, -105.0372046]
}

df_kota = pd.DataFrame(kota)
df_kota
# Out:
#             area   latitude   longitude
# 0  Tower Hamlets  51.520261   -0.029340
# 1         Newham  51.525516    0.035216
# 2      Southwark  51.502781   -0.087738
# 3        Lambeth  51.457148   -0.123068
# 4    Westminster  39.836653 -105.037205

# %%
top5area = folium.map.FeatureGroup()

for lat, lng, in zip(df_kota.latitude, df_kota.longitude):
    top5area.add_child(
        folium.CircleMarker(
           location= [lat, lng],
           radius=5,
           color='red',
           fill=True,
           fill_color='blue',
           fill_opacity=0.6
        )  
    )
london.add_child(top5area)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...
